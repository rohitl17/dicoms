# %%
import pydicom

# %%
dcm=pydicom.read_file('/opt/bucketdata/japan_decompress_dicom/1.2.392.200036.9107.307.12321.20180827.110645.1094050.dcm')

# %%
import matplotlib.pyplot as plt
import cv2

img=cv2.imread('/opt/bucketdata/japan_decompress_dicom_png/1.2.392.200036.9107.307.12321.20180827.110645.1094050.png')

# print (dcm.BodyPartExamined)
# print (dcm.PhotometricInterpretation)

plt.imshow(img)

# %%
dcm
# Out:
# (0008, 0005) Specific Character Set              CS: ['', 'ISO 2022 IR 87', 'ISO 2022 IR 13']
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: Computed Radiography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.392.200036.9107.307.12321.20180827.110645.1094050
# (0008, 0020) Study Date                          DA: '20180827'
# (0008, 0023) Content Date                        DA: '20180827'
# (0008, 0030) Study Time                          TM: '105758'
# (0008, 0033) Content Time                        TM: '110042'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0070) Manufacturer                        LO: ''
# (0008, 0080) Institution Name                    LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'CS-7'
# ...

# %%
import numpy as np
np.sum(cv2.resize(img, (224,224)))
# Out:
# 19325310

# %%
dcm=pydicom.read_file('/opt/bucketdata/japan_decompress_dicom/1.2.392.200036.9125.4.0.437210163.772537876.4222981831.dcm')

img=cv2.imread('/opt/bucketdata/japan_decompress_dicom_png/1.2.392.200036.9125.4.0.437210163.772537876.4222981831.png')
plt.imshow(img)
print (dcm.BodyPartExamined)
print (dcm.PhotometricInterpretation)
# Out:
# CHEST
# MONOCHROME2

# %%
np.sum(cv2.resize(img, (224,224)))
# Out:
# 13830489

# %%
np.average(img)
# Out:
# 91.96261745166383

# %%
dcm=pydicom.read_file('/opt/bucketdata/japan_decompress_dicom/1.2.392.200036.9107.1.1.20180111.130737.102414.dcm')

img=cv2.imread('/opt/bucketdata/japan_decompress_dicom_png/1.2.392.200036.9107.1.1.20180111.130737.102414.png')
plt.imshow(img)
print (dcm.BodyPartExamined)
print (dcm.PhotometricInterpretation)

dcm
# Out:
# CHEST
# MONOCHROME2
# (0008, 0005) Specific Character Set              CS: ['', 'ISO 2022 IR 87', 'ISO 2022 IR 13']
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'POST_PROCESSED']
# (0008, 0016) SOP Class UID                       UI: Computed Radiography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.392.200036.9107.1.1.20180111.130737.102414
# (0008, 0020) Study Date                          DA: '20180110'
# (0008, 0022) Acquisition Date                    DA: '20180111'
# (0008, 0023) Content Date                        DA: '20180110'
# (0008, 0030) Study Time                          TM: '091827'
# (0008, 0032) Acquisition Time                    TM: '130737'
# (0008, 0033) Content Time                        TM: '092018'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0070) Manufacturer                        LO: ''
# ...

# %%
np.sum(cv2.resize(img, (224,224)))
# Out:
# 19507482

# %%
dcm=pydicom.read_file('/opt/bucketdata/japan_decompress_dicom/1.2.392.200036.9107.433.501.6533.1.1.20180409.94127.103148.dcm')

img=cv2.imread('/opt/bucketdata/japan_decompress_dicom_png/1.2.392.200036.9107.433.501.6533.1.1.20180409.94127.103148.png')
plt.imshow(img)
print (dcm.BodyPartExamined)
print (dcm.PhotometricInterpretation)

dcm
# Out:
# CHEST
# MONOCHROME2
# (0008, 0005) Specific Character Set              CS: ['', 'ISO 2022 IR 87', 'ISO 2022 IR 13']
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'POST_PROCESSED']
# (0008, 0016) SOP Class UID                       UI: Computed Radiography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.392.200036.9107.433.501.6533.1.1.20180409.94127.103148
# (0008, 0020) Study Date                          DA: '20180409'
# (0008, 0022) Acquisition Date                    DA: '20180409'
# (0008, 0023) Content Date                        DA: '20180409'
# (0008, 0030) Study Time                          TM: '235959'
# (0008, 0032) Acquisition Time                    TM: '094127'
# (0008, 0033) Content Time                        TM: '235959'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0070) Manufacturer                        LO: ''
# ...
